# %%
import pandas as pd
import matplotlib.pyplot as plt

dataframe = pd.read_csv("MeatBallTemp.csv")
x = dataframe[dataframe.columns[0]]
y = dataframe[dataframe.columns[1]]
dataframe.tail()
plt.xlabel(dataframe.columns[0])
plt.ylabel(dataframe.columns[1])

fig_size = plt.rcParams["figure.figsize"]
#fig_size[0] = 80
#fig_size[1] = 20

plt.plot(x, y)
plt.show()  # or plt.savefig("name.png")

print("Current size:", fig_size)
# Out:
# Current size: [6.0, 4.0]

# %%
minwavelength = 380
maxwavelength = 480
filename = "PalmOilclbWater"

# %%
import pandas as pd
import matplotlib.pyplot as plt
rawdata = pd.read_csv(filename+".csv") 

listofcol=list(rawdata.columns)
listofAbs=[]

for i in range(0,len(listofcol),2):
    listofAbs.append(listofcol[i+1])
    
fig = df.plot(x=rawdata.columns[0], y= listofAbs, figsize=(18,10), grid=True,)

fig.set_xlim(minwavelength,maxwavelength)
fig.set_xlabel("Wavelength(nm)")
fig.set_ylabel("Absorbance")
fig.tick_params(axis="x", labelsize=16)
fig.tick_params(axis="y", labelsize=16)
