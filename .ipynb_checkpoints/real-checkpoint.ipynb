# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image 
import time
from skimage import io
from skimage.morphology import convex_hull_image
from skimage.measure import label, regionprops
from skimage.color import rgb2gray
from PIL import Image 
import coremltools 
import serial
import os

# %%
ser =serial.Serial('/dev/cu.usbmodem14101',9600)
model = coremltools.models.MLModel('Model/CCNC.mlmodel')
cap=cv2.VideoCapture(0)
needplot=False
queue=[]
#queue cell {time:,grb:}
#time.time()

# %%
#new
c50=0
c100=0
lastrequest=0
queue=[]
while True: 
    #print(".",end='')
    if len(queue)>0:
        #print("compare",queue[0]['time']+12,time.time())
        if queue[0]['time']+0<=time.time():                                                  #delay
            print("@@@@time is come" ,queue[0]['time'],queue[0]['grb'])
            if queue[0]['grb']:
                command=str.encode('0')
                ser.write(command)
            else:
                command=str.encode('1')
                ser.write(command)
            del queue[0]
            continue
    
    #Wait for arduino to write
                #waitforreq=ser.read_until()
    if(ser.in_waiting):
        waitforreq=ser.readline()
    else:
        continue
    #Display serial
    print("serial say : ",waitforreq)
    print("Requset code : ",waitforreq[0])
    
    #Check is that really come from arduino
    if (waitforreq[0]!=50):
        continue
    if (time.time()-lastrequest<=0.5):
        lastrequest=time.time()
        continue
    else:
        lastrequest=time.time()
    time.sleep(1)
    #Try capture till got photo
    ret=False
    while (ret==False):
        print("Cam!")
        ret, frame = cap.read() # ret is boolean for pic avalble or not
    
    print("Cam've got shot!")
    
    frame=frame[...,::-1] # cv2 BRG to RGB
    frame=np.rot90(frame, 0, ) # rotate 90 degrees
    frame=frame[:,720:1500] #crop the photo                                             cam calibrate
    
    #Show raw photo
    if needplot:
        plt.imshow(frame)
        plt.show()

    #Calculate binary from R:G:B 1:1:0 and not black pixel R+G+B>700 is black
    binary=((((frame[:,:,0]/frame[:,:,2])+(frame[:,:,1]/frame[:,:,2]))>2.1)&(frame[:,:,0]+frame[:,:,1]+frame[:,:,2]<=700))
    
    #Show first binary
    plt.imshow(binary)
    plt.show()
    
    #Start label first binary
    labelframe=label(binary)
    regiongrframe=regionprops(labelframe)

    print("Start find the nearest chillie.")
    
    labelreal=-1 #lable that we choses defult -1
    yreal=0 #Parameter for dowst chilie
    minr, minc, maxr, maxc=0,0,0,0
    for j in range(len(regiongrframe)):
        area=regiongrframe[j].area
        y0,x0=regiongrframe[j].centroid
        #if area pixel less than 9000 assume as noise
        if area<9000:
            pass
        elif(y0>yreal and abs(385-x0)<=300):                                         #cam
            labelreal= regiongrframe[j].label
            yreal=y0
            minr, minc, maxr, maxc = regiongrframe[j].bbox
    
    #Notting deteccted
    if(labelreal==-1):
        print("-------->no detection")
        queue.append({'time':time.time(),'grb':False})
        continue
    
    print("Deleting noise",labelreal)
    #New binary without noise
    binary=(labelframe==labelreal)
    #New frame with Black background
    frame[:,:,0]=frame[:,:,0]*binary
    frame[:,:,1]=frame[:,:,1]*binary
    frame[:,:,2]=frame[:,:,2]*binary
    
    #Crop img
    print("Cropping photo : ",minr,minc, maxr, maxc)
    binary=binary[minr:maxr+1,minc:maxc+1]
    frame=frame[minr:maxr+1,minc:maxc+1,:]

    print("check4")
    R=frame[:,:,0]
    G=frame[:,:,1]
    B=frame[:,:,2]
    #meanofrgb=(R+G+B)/1.65
    
    #biforblen is a binary of Chilie without tail
    print("Detecting tail")
    biforblen=(binary&(R>G*1.8)).copy()
    
    #Show tail (biforblen!=binary)=tail
    if needplot:
        plt.imshow(biforblen!=binary)
        plt.show()
    
    print("tail pixel : ",np.sum(biforblen!=binary))
    
    #if tail pixel less than 2000 mean no tail
    if (np.sum(biforblen!=binary)<2000):
        print("-------->No tail detected")
        #Sent false to arduino
        queue.append({'time':time.time(),'grb':False})
        continue
    
    #groupping the real chilie body without tail
    labelframeforblen=label(biforblen)
    regiongrframeforblen=regionprops(labelframeforblen)

    print("Start scope for blen.")
    
    labelrealforblen=-1
    #yrealforblen keep maximum 
    yrealforblen=0
    minr, minc, maxr, maxc=0,0,0,0
    for j in range(len(regiongrframeforblen)):
        area=regiongrframeforblen[j].area
            #y0,x0=regiongrframeforblen[j].centroid
        #if area less that 9000px assume as noise
        if area<9000:
            pass
        elif(area>yrealforblen):
            labelrealforblen= regiongrframeforblen[j].label
            yrealforblen=area
            minr, minc, maxr, maxc = regiongrframeforblen[j].bbox  
    
    #Crop binary for convexhull
    biforblen=biforblen[minr:maxr+1,minc:maxc+1].copy()

    print("Calculate blend using convex" ,biforblen.shape )
    if needplot:
        plt.imshow(biforblen)
        plt.show()
        
        
    sumbiforblen=np.sum(biforblen)           #new
    print("pixel : ",sumbiforblen)
    
    #Body of chillie less than 43000 assume as small or green ones
    
    #new---
    if (sumbiforblen>=65000):
        print("-------->it broked")
        queue.append({'time':time.time(),'grb':False})
        continue
    #new---
    
    
    if (sumbiforblen<=24010):
        print("-------->it green or too small")
        queue.append({'time':time.time(),'grb':False})
        continue
    
    #try assing convex hull to cvh
    try :
        cvh=convex_hull_image(biforblen)
    except:
        print("!!!!!!!!!convexhull not working!")
        cvh=biforblen
        
    #show covex hull
    if needplot:
        plt.imshow(cvh)
        plt.show()

    #if binary/convex hull less than 65 assume it is bleded
    if (sumbiforblen*100/np.sum(cvh)<63):
        #return false
        print("-------->No it's blend : ",sumbiforblen*100/np.sum(cvh))
        queue.append({'time':time.time(),'grb':False})
        continue
    
    print("Transforme background to white")
    frame[(R+G+B)==0]=255
    img=Image.fromarray(frame)
    print("Calculating colour.")
    
    if needplot:
        plt.imshow(frame)
        plt.show()
    
    #Predict by ML model
    predict=model.predict({'image': img})['classLabel']
    
    #Good chilie detected
    if(predict=='red' or predict=='yellow' or predict=="orange"):
        #return true
        print("-------->Good chilie")
        queue.append({'time':time.time(),'grb':True})
    else:
            #return false
        print("-------->chilie colour not good",predict)
        queue.append({'time':time.time(),'grb':False})
    print("donee")
# Out:
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: divide by zero encountered in true_divide
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820901.7883039 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820905.066498 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820906.317937 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820910.572465 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 37
# Cropping photo :  394 54 794 780
# check4
# Detecting tail
# tail pixel :  23955
# Start scope for blen.
# Calculate blend using convex (166, 673)
# pixel :  34624
# -------->No it's blend :  57.3777011799019
# @@@@time is come 1576820921.321575 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: invalid value encountered in true_divide
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: invalid value encountered in greater
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820929.059671 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 88
# Cropping photo :  394 80 940 780
# check4
# Detecting tail
# tail pixel :  23348
# Start scope for blen.
# Calculate blend using convex (99, 525)
# pixel :  23258
# -------->it green or too small
# @@@@time is come 1576820933.2626271 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 70
# Cropping photo :  394 82 942 780
# check4
# Detecting tail
# tail pixel :  23841
# Start scope for blen.
# Calculate blend using convex (101, 525)
# pixel :  22846
# -------->it green or too small
# @@@@time is come 1576820934.577023 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 2
# Cropping photo :  0 90 903 780
# check4
# Detecting tail
# tail pixel :  194006
# Start scope for blen.
# Calculate blend using convex (237, 507)
# pixel :  42109
# -------->No it's blend :  54.703352949582346
# @@@@time is come 1576820943.2333581 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 117
# Cropping photo :  860 181 1062 712
# check4
# Detecting tail
# tail pixel :  63142
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576820946.713314 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 121
# Cropping photo :  856 180 1054 708
# check4
# Detecting tail
# tail pixel :  62098
# Start scope for blen.
# Calculate blend using convex (159, 521)
# pixel :  10326
# -------->it green or too small
# @@@@time is come 1576820950.416817 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 130
# Cropping photo :  858 182 1056 712
# check4
# Detecting tail
# tail pixel :  63325
# Start scope for blen.
# Calculate blend using convex (167, 523)
# pixel :  10312
# -------->it green or too small
# @@@@time is come 1576820951.683732 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 129
# Cropping photo :  423 124 988 780
# check4
# Detecting tail
# tail pixel :  3795
# Start scope for blen.
# Calculate blend using convex (395, 614)
# pixel :  52668
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576820959.212672 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820985.688895 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820986.955738 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820988.2176561 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820989.4621608 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820990.7125099 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820991.972575 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820993.229582 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820994.542662 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576820995.7704089 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 28
# Cropping photo :  392 154 890 780
# check4
# Detecting tail
# tail pixel :  38507
# Start scope for blen.
# Calculate blend using convex (247, 618)
# pixel :  64960
# -------->No it's blend :  52.096783248189524
# @@@@time is come 1576821003.979309 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576821005.397511 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 26
# Cropping photo :  276 115 844 290
# check4
# Detecting tail
# tail pixel :  3876
# Start scope for blen.
# Calculate blend using convex (472, 111)
# pixel :  26972
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821006.820141 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576821008.1324968 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576821009.389502 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 17
# Cropping photo :  272 184 940 608
# check4
# Detecting tail
# tail pixel :  39501
# Start scope for blen.
# Calculate blend using convex (555, 163)
# pixel :  45181
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821014.865088 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 44
# Cropping photo :  570 242 1080 368
# check4
# Detecting tail
# tail pixel :  5793
# Start scope for blen.
# Calculate blend using convex (381, 123)
# pixel :  24423
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821017.649655 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576821018.864927 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 15
# Cropping photo :  278 154 1080 369
# check4
# Detecting tail
# tail pixel :  16388
# Start scope for blen.
# Calculate blend using convex (621, 195)
# pixel :  60294
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821030.679641 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 31
# Cropping photo :  254 324 860 522
# check4
# Detecting tail
# tail pixel :  13364
# Start scope for blen.
# Calculate blend using convex (419, 129)
# pixel :  25125
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821032.180306 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576821033.420695 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 2
# Cropping photo :  0 0 1060 780
# check4
# Detecting tail
# tail pixel :  250951
# Start scope for blen.
# Calculate blend using convex (908, 565)
# pixel :  205789
# -------->No it's blend :  60.00571513548662
# @@@@time is come 1576821048.883648 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 19
# Cropping photo :  201 224 1080 578
# check4
# Detecting tail
# tail pixel :  44464
# Start scope for blen.
# Calculate blend using convex (604, 217)
# pixel :  74004
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821050.361731 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 261
# Cropping photo :  732 106 1080 434
# check4
# Detecting tail
# tail pixel :  12555
# Start scope for blen.
# Calculate blend using convex (336, 299)
# pixel :  50181
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821051.781922 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 454
# Cropping photo :  784 330 1080 566
# check4
# Detecting tail
# tail pixel :  10856
# Start scope for blen.
# Calculate blend using convex (258, 125)
# pixel :  19061
# -------->it green or too small
# @@@@time is come 1576821053.0633972 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 624
# Cropping photo :  870 304 1016 740
# check4
# Detecting tail
# tail pixel :  22453
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576821054.352392 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 47
# Cropping photo :  404 126 1080 472
# check4
# Detecting tail
# tail pixel :  81920
# Start scope for blen.
# Calculate blend using convex (597, 168)
# pixel :  41966
# -------->No it's blend :  52.51263827018369
# @@@@time is come 1576821057.368685 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 2
# Cropping photo :  0 0 498 372
# check4
# Detecting tail
# tail pixel :  67055
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576821058.650366 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576821059.906559 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 32
# Cropping photo :  414 312 1016 620
# check4
# Detecting tail
# tail pixel :  41669
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576821062.6571531 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 58
# Cropping photo :  640 226 906 640
# check4
# Detecting tail
# tail pixel :  7119
# Start scope for blen.
# Calculate blend using convex (263, 409)
# pixel :  34018
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821064.0459871 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576821065.2977312 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 43
# Cropping photo :  484 320 996 552
# check4
# Detecting tail
# tail pixel :  48055
# Start scope for blen.
# Calculate blend using convex (377, 149)
# pixel :  10711
# -------->it green or too small
# @@@@time is come 1576821071.277477 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 2
# Cropping photo :  0 230 1040 644
# check4
# Detecting tail
# tail pixel :  26513
# Start scope for blen.
# Calculate blend using convex (617, 197)
# pixel :  54879
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821075.9894311 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 266
# Cropping photo :  928 174 1080 400
# check4
# Detecting tail
# tail pixel :  9668
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576821078.756732 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 3
# Cropping photo :  0 218 844 780
# check4
# Detecting tail
# tail pixel :  82190
# Start scope for blen.
# Calculate blend using convex (603, 287)
# pixel :  72491
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821081.224292 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 19
# Cropping photo :  394 56 1022 332
# check4
# Detecting tail
# tail pixel :  5511
# Start scope for blen.
# Calculate blend using convex (517, 191)
# pixel :  35944
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821086.427016 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 19
# Cropping photo :  200 294 722 460
# check4
# Detecting tail
# tail pixel :  25127
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576821087.703659 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 67
# Cropping photo :  674 261 1080 500
# check4
# Detecting tail
# tail pixel :  8122
# Start scope for blen.
# Calculate blend using convex (406, 236)
# pixel :  50884
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821089.185709 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 71
# Cropping photo :  674 252 1080 502
# check4
# Detecting tail
# tail pixel :  9404
# Start scope for blen.
# Calculate blend using convex (404, 245)
# pixel :  52093
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821118.325732 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 51
# Cropping photo :  670 256 1080 500
# check4
# Detecting tail
# tail pixel :  9730
# Start scope for blen.
# Calculate blend using convex (406, 241)
# pixel :  51329
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576821130.241237 True
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-17e37eea1601> in <module>
#      21     #Wait for arduino to write
#      22                 #waitforreq=ser.read_until()
# ---> 23     if(ser.in_waiting):
#      24         waitforreq=ser.readline()
#      25     else:
#
# ~/anaconda3/lib/python3.7/site-packages/serial/serialposix.py in in_waiting(self)
#     465         """Return the number of bytes currently in the input buffer."""
#     466         #~ s = fcntl.ioctl(self.fd, termios.FIONREAD, TIOCM_zero_str)
# --> 467         s = fcntl.ioctl(self.fd, TIOCINQ, TIOCM_zero_str)
#     468         return struct.unpack('I', s)[0]
#     469
#
# OSError: [Errno 6] Device not configured

# %%
print(queue)
print(time.time())
# Out:
# [{'time': 1576783444.0862029, 'grb': True}, {'time': 1576783448.521217, 'grb': False}]
# 1576783546.896659

# %%
c50=0
c100=0
while True:    
    #Wait for arduino to write
    waitforreq=ser.read_until()
    #Display serial
    print("serial say : ",waitforreq)
    print("Requset code : ",waitforreq[0])
    if(waitforreq[0]==50):
        c50=c50+1
    elif(waitforreq[0]==100):
        c100=c100+1
    #Check is that really come from arduino
    if (waitforreq[0]!=50):
        continue
    
    #Try capture till got photo
    ret=False
    while (ret==False):
        print("Cam!")
        ret, frame = cap.read() # ret is boolean for pic avalble or not
    
    print("Cam've got shot!")
    
    frame=frame[...,::-1] # cv2 BRG to RGB
    frame=np.rot90(frame, 0, ) # rotate 90 degrees
    frame=frame[:,:] #crop the photo
    
    #Show raw photo
    if needplot:
        plt.imshow(frame)
        plt.show()

    #Calculate binary from R:G:B 1:1:0 and not black pixel R+G+B>700 is black
    binary=((((frame[:,:,0]/frame[:,:,2])+(frame[:,:,1]/frame[:,:,2]))>2.1)&(frame[:,:,0]+frame[:,:,1]+frame[:,:,2]<=700))
    
    #Show first binary
    plt.imshow(binary)
    plt.show()
    
    #Start label first binary
    labelframe=label(binary)
    regiongrframe=regionprops(labelframe)

    print("Start find the nearest chillie.")
    
    labelreal=-1 #lable that we choses defult -1
    yreal=0 #Parameter for dowst chilie
    minr, minc, maxr, maxc=0,0,0,0
    for j in range(len(regiongrframe)):
        area=regiongrframe[j].area
        y0,x0=regiongrframe[j].centroid
        #if area pixel less than 9000 assume as noise
        if area<9000:
            pass
        elif(y0>yreal and abs(750-x0)<=300):
            labelreal= regiongrframe[j].label
            yreal=y0
            minr, minc, maxr, maxc = regiongrframe[j].bbox
    
    #Notting deteccted
    if(labelreal==-1):
        print("-------->no detection")
        command=str.encode('0')
        ser.write(command)
        continue
    
    print("Deleting noise",labelreal)
    #New binary without noise
    binary=(labelframe==labelreal)
    #New frame with Black background
    frame[:,:,0]=frame[:,:,0]*binary
    frame[:,:,1]=frame[:,:,1]*binary
    frame[:,:,2]=frame[:,:,2]*binary
    
    #Crop img
    print("Cropping photo : ",minr,minc, maxr, maxc)
    binary=binary[minr:maxr+1,minc:maxc+1]
    frame=frame[minr:maxr+1,minc:maxc+1,:]

    print("check4")
    R=frame[:,:,0]
    G=frame[:,:,1]
    B=frame[:,:,2]
    #meanofrgb=(R+G+B)/1.65
    
    #biforblen is a binary of Chilie without tail
    print("Detecting tail")
    biforblen=(binary&(R>G*1.8)).copy()
    
    #Show tail (biforblen!=binary)=tail
    if needplot:
        plt.imshow(biforblen!=binary)
        plt.show()
    
    print("tail pixel : ",np.sum(biforblen!=binary))
    
    #if tail pixel less than 2000 mean no tail
    if (np.sum(biforblen!=binary)<2000):
        print("-------->No tail detected")
        #Sent false to arduino
        command=str.encode('0')
        ser.write(command)
        continue
    
    #groupping the real chilie body without tail
    labelframeforblen=label(biforblen)
    regiongrframeforblen=regionprops(labelframeforblen)

    print("Start scope for blen.")
    
    labelrealforblen=-1
    #yrealforblen keep maximum 
    yrealforblen=0
    minr, minc, maxr, maxc=0,0,0,0
    for j in range(len(regiongrframeforblen)):
        area=regiongrframeforblen[j].area
            #y0,x0=regiongrframeforblen[j].centroid
        #if area less that 9000px assume as noise
        if area<9000:
            pass
        elif(area>yrealforblen):
            labelrealforblen= regiongrframeforblen[j].label
            yrealforblen=area
            minr, minc, maxr, maxc = regiongrframeforblen[j].bbox  
    
    #Crop binary for convexhull
    biforblen=biforblen[minr:maxr+1,minc:maxc+1].copy()

    print("Calculate blend using convex" ,biforblen.shape )
    if needplot:
        plt.imshow(biforblen)
        plt.show()
    print("pixel : ",np.sum(biforblen))
    
    #Body of chillie less than 43000 assume as small or green ones
    if (np.sum(biforblen)<=24010):
        print("-------->it green or too small")
        command=str.encode('0')
        ser.write(command)
        continue
    
    #try assing convex hull to cvh
    try :
        cvh=convex_hull_image(biforblen)
    except:
        print("!!!!!!!!!convexhull not working!")
        cvh=biforblen
        
    #show covex hull
    if needplot:
        plt.imshow(cvh)
        plt.show()

    #if binary/convex hull less than 65 assume it is bleded
    if (np.sum(biforblen)*100/np.sum(cvh)<63):
        #return false
        print("-------->No it's blend : ",np.sum(biforblen)*100/np.sum(cvh))
        command=str.encode('0')
        ser.write(command)
        continue
    
    print("Transforme background to white")
    frame[(R+G+B)==0]=255
    img=Image.fromarray(frame)
    print("Calculating colour.")
    
    if needplot:
        plt.imshow(frame)
        plt.show()
    
    #Predict by ML model
    predict=model.predict({'image': img})['classLabel']
    
    #Good chilie detected
    if(predict=='red' or predict=='yellow' or predict=="orange"):
        #return true
        print("-------->Good chilie")
        command=str.encode('1')
        ser.write(command)
    else:
            #return false
        print("-------->chilie colour not good",predict)
        command=str.encode('0')
        ser.write(command)
    print("donee")
# Out:
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in greater
# Start find the nearest chillie.
# Deleting noise 268
# Cropping photo :  190 838 934 986
# check4
# Detecting tail
# tail pixel :  2418
# Start scope for blen.
# Calculate blend using convex (611, 98)
# pixel :  39119
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# serial say :  b'queue : 2413200\r\n'
# Requset code :  113
# serial say :  b'dobad 2\r\n'
# Requset code :  100
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/serial/serialposix.py in read(self, size)
#     492                     break   # timeout
# --> 493                 buf = os.read(self.fd, size - len(read))
#     494                 # read should always return some data as select reported it was
#
# OSError: [Errno 6] Device not configured
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-6-fd7a93a64da0> in <module>
#       3 while True:
#       4     #Wait for arduino to write
# ----> 5     waitforreq=ser.read_until()
#       6     #Display serial
#       7     print("serial say : ",waitforreq)
#
# ~/anaconda3/lib/python3.7/site-packages/serial/serialutil.py in read_until(self, terminator, size)
#     657         timeout = Timeout(self._timeout)
#     658         while True:
# --> 659             c = self.read(1)
#     660             if c:
#     661                 line += c
#
# ~/anaconda3/lib/python3.7/site-packages/serial/serialposix.py in read(self, size)
#     507                 # https://www.python.org/dev/peps/pep-0475.
#     508                 if e.errno not in (errno.EAGAIN, errno.EALREADY, errno.EWOULDBLOCK, errno.EINPROGRESS, errno.EINTR):
# --> 509                     raise SerialException('read failed: {}'.format(e))
#     510             except select.error as e:
#     511                 # this is for Python 2.x
#
# SerialException: read failed: [Errno 6] Device not configured

# %%
print(c50,c100)
# Out:
# 11 7
