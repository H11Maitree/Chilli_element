# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image 
import time
from skimage import io
from skimage.morphology import convex_hull_image
from skimage.measure import label, regionprops
from skimage.color import rgb2gray
from PIL import Image 
import coremltools 
import serial
import os

# %%
ser =serial.Serial('/dev/cu.usbmodem14201',9600)
model = coremltools.models.MLModel('Model/CCNC.mlmodel')
cap=cv2.VideoCapture(1)
needplot=True
queue=[]
#queue cell {time:,grb:}
#time.time()

# %%
#new
c50=0
c100=0
lastrequest=0
queue=[]
while True: 
    #print(".",end='')
    if len(queue)>0:
        #print("compare",queue[0]['time']+12,time.time())
        if queue[0]['time']<=time.time():
            print("@@@@time is come" ,queue[0]['time'],queue[0]['grb'])
            if queue[0]['grb']:
                command=str.encode('0')
                ser.write(command)
            else:
                command=str.encode('1')
                ser.write(command)
            del queue[0]
            continue
    
    #Wait for arduino to write
                #waitforreq=ser.read_until()
    if(ser.in_waiting):
        waitforreq=ser.readline()
    else:
        continue
    #Display serial
    print("serial say : ",waitforreq)
    print("Requset code : ",waitforreq[0])
    
    #Check is that really come from arduino
    if (waitforreq[0]!=50):
        continue
    if (time.time()-lastrequest<=1.5):
        lastrequest=time.time()
        continue
    else:
        lastrequest=time.time()
    time.sleep(1)
    #Try capture till got photo
    ret=False
    while (ret==False):
        print("Cam!")
        ret, frame = cap.read() # ret is boolean for pic avalble or not
    
    print("Cam've got shot!")
    
    frame=frame[...,::-1] # cv2 BRG to RGB
    frame=np.rot90(frame, 0, ) # rotate 90 degrees
    frame=frame[:,760:760+750] #crop the photo
    
    #Show raw photo
    if needplot:
        plt.imshow(frame)
        plt.show()

    #Calculate binary from R:G:B 1:1:0 and not black pixel R+G+B>700 is black
    binary=((((frame[:,:,0]/frame[:,:,2])+(frame[:,:,1]/frame[:,:,2]))>2.1)&(frame[:,:,0]+frame[:,:,1]+frame[:,:,2]<=700))
    
    #Show first binary
    plt.imshow(binary)
    plt.show()
    
    #Start label first binary
    labelframe=label(binary)
    regiongrframe=regionprops(labelframe)

    print("Start find the nearest chillie.")
    
    labelreal=-1 #lable that we choses defult -1
    yreal=0 #Parameter for dowst chilie
    minr, minc, maxr, maxc=0,0,0,0
    for j in range(len(regiongrframe)):
        area=regiongrframe[j].area
        y0,x0=regiongrframe[j].centroid
        #if area pixel less than 9000 assume as noise
        if area<9000:
            pass
        elif(y0>yreal and abs(400-x0)<=300):
            labelreal= regiongrframe[j].label
            yreal=y0
            minr, minc, maxr, maxc = regiongrframe[j].bbox
    
    #Notting deteccted
    if(labelreal==-1):
        print("-------->no detection")
        queue.append({'time':time.time(),'grb':False})
        continue
    
    print("Deleting noise",labelreal)
    #New binary without noise
    binary=(labelframe==labelreal)
    #New frame with Black background
    frame[:,:,0]=frame[:,:,0]*binary
    frame[:,:,1]=frame[:,:,1]*binary
    frame[:,:,2]=frame[:,:,2]*binary
    
    #Crop img
    print("Cropping photo : ",minr,minc, maxr, maxc)
    binary=binary[minr:maxr+1,minc:maxc+1]
    frame=frame[minr:maxr+1,minc:maxc+1,:]

    print("check4")
    R=frame[:,:,0]
    G=frame[:,:,1]
    B=frame[:,:,2]
    #meanofrgb=(R+G+B)/1.65
    
    #biforblen is a binary of Chilie without tail
    print("Detecting tail")
    biforblen=(binary&(R>G*1.8)).copy()
    
    #Show tail (biforblen!=binary)=tail
    if needplot:
        plt.imshow(biforblen!=binary)
        plt.show()
    
    print("tail pixel : ",np.sum(biforblen!=binary))
    
    #if tail pixel less than 2000 mean no tail
    if (np.sum(biforblen!=binary)<2000):
        print("-------->No tail detected")
        #Sent false to arduino
        queue.append({'time':time.time(),'grb':False})
        continue
    
    #groupping the real chilie body without tail
    labelframeforblen=label(biforblen)
    regiongrframeforblen=regionprops(labelframeforblen)

    print("Start scope for blen.")
    
    labelrealforblen=-1
    #yrealforblen keep maximum 
    yrealforblen=0
    minr, minc, maxr, maxc=0,0,0,0
    for j in range(len(regiongrframeforblen)):
        area=regiongrframeforblen[j].area
            #y0,x0=regiongrframeforblen[j].centroid
        #if area less that 9000px assume as noise
        if area<9000:
            pass
        elif(area>yrealforblen):
            labelrealforblen= regiongrframeforblen[j].label
            yrealforblen=area
            minr, minc, maxr, maxc = regiongrframeforblen[j].bbox  
    
    #Crop binary for convexhull
    biforblen=biforblen[minr:maxr+1,minc:maxc+1].copy()

    print("Calculate blend using convex" ,biforblen.shape )
    if needplot:
        plt.imshow(biforblen)
        plt.show()
    print("pixel : ",np.sum(biforblen))
    
    #Body of chillie less than 43000 assume as small or green ones
    if (np.sum(biforblen)<=24010):
        print("-------->it green or too small")
        queue.append({'time':time.time(),'grb':False})
        continue
    
    #try assing convex hull to cvh
    try :
        cvh=convex_hull_image(biforblen)
    except:
        print("!!!!!!!!!convexhull not working!")
        cvh=biforblen
        
    #show covex hull
    if needplot:
        plt.imshow(cvh)
        plt.show()

    #if binary/convex hull less than 65 assume it is bleded
    if (np.sum(biforblen)*100/np.sum(cvh)<63):
        #return false
        print("-------->No it's blend : ",np.sum(biforblen)*100/np.sum(cvh))
        queue.append({'time':time.time(),'grb':False})
        continue
    
    print("Transforme background to white")
    frame[(R+G+B)==0]=255
    img=Image.fromarray(frame)
    print("Calculating colour.")
    
    if needplot:
        plt.imshow(frame)
        plt.show()
    
    #Predict by ML model
    predict=model.predict({'image': img})['classLabel']
    
    #Good chilie detected
    if(predict=='red' or predict=='yellow' or predict=="orange"):
        #return true
        print("-------->Good chilie")
        queue.append({'time':time.time(),'grb':True})
    else:
            #return false
        print("-------->chilie colour not good",predict)
        queue.append({'time':time.time(),'grb':False})
    print("donee")
# Out:
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: divide by zero encountered in true_divide
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: invalid value encountered in true_divide
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: invalid value encountered in greater
# Start find the nearest chillie.
# Deleting noise 35
# Cropping photo :  416 324 838 432
# check4
# Detecting tail
# tail pixel :  29039
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576786468.104832 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 1
# Cropping photo :  0 570 280 750
# check4
# Detecting tail
# tail pixel :  34572
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576786482.861283 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 3
# Cropping photo :  0 568 280 750
# check4
# Detecting tail
# tail pixel :  34598
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576786484.7347891 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 57
# Cropping photo :  704 190 1080 300
# check4
# Detecting tail
# tail pixel :  6807
# Start scope for blen.
# Calculate blend using convex (240, 107)
# pixel :  17370
# -------->it green or too small
# @@@@time is come 1576786494.5442371 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 1
# Cropping photo :  0 134 627 226
# check4
# Detecting tail
# tail pixel :  4626
# Start scope for blen.
# Calculate blend using convex (489, 91)
# pixel :  25217
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576786496.9401011 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576786498.544189 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 37
# Cropping photo :  358 164 956 390
# check4
# Detecting tail
# tail pixel :  3212
# Start scope for blen.
# Calculate blend using convex (453, 225)
# pixel :  28699
# -------->No it's blend :  61.36723260488389
# @@@@time is come 1576786504.939587 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 39
# Cropping photo :  492 136 1080 428
# check4
# Detecting tail
# tail pixel :  9970
# Start scope for blen.
# Calculate blend using convex (369, 231)
# pixel :  23523
# -------->it green or too small
# @@@@time is come 1576786513.13104 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576786514.594177 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 38
# Cropping photo :  455 236 1080 434
# check4
# Detecting tail
# tail pixel :  5051
# Start scope for blen.
# Calculate blend using convex (582, 187)
# pixel :  37072
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576786525.86028 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 185
# Cropping photo :  386 0 918 370
# check4
# Detecting tail
# tail pixel :  44825
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576786535.4771662 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576786586.108277 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 115
# Cropping photo :  334 226 980 574
# check4
# Detecting tail
# tail pixel :  10051
# Start scope for blen.
# Calculate blend using convex (570, 281)
# pixel :  48016
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576786614.648823 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 195
# Cropping photo :  488 196 1014 300
# check4
# Detecting tail
# tail pixel :  32931
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576786624.067339 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 266
# Cropping photo :  614 408 1080 670
# check4
# Detecting tail
# tail pixel :  4272
# Start scope for blen.
# Calculate blend using convex (462, 231)
# pixel :  31823
# -------->No it's blend :  56.652780744855086
# @@@@time is come 1576786630.789973 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 170
# Cropping photo :  324 352 1007 534
# check4
# Detecting tail
# tail pixel :  7158
# Start scope for blen.
# Calculate blend using convex (651, 167)
# pixel :  52151
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576786638.768806 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 215
# Cropping photo :  468 230 984 352
# check4
# Detecting tail
# tail pixel :  32909
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576786646.92664 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 78
# Cropping photo :  416 516 544 702
# check4
# Detecting tail
# tail pixel :  9208
# Start scope for blen.
# Calculate blend using convex (1, 1)
# pixel :  0
# -------->it green or too small
# @@@@time is come 1576786663.82543 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576786669.1037152 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 84
# Cropping photo :  522 328 1080 454
# check4
# Detecting tail
# tail pixel :  7252
# Start scope for blen.
# Calculate blend using convex (554, 127)
# pixel :  33721
# -------->No it's blend :  56.55039409693107
# @@@@time is come 1576786677.537034 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 58
# Cropping photo :  314 334 988 504
# check4
# Detecting tail
# tail pixel :  7400
# Start scope for blen.
# Calculate blend using convex (641, 165)
# pixel :  49971
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576786684.8852322 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 74
# Cropping photo :  390 338 960 504
# check4
# Detecting tail
# tail pixel :  2522
# Start scope for blen.
# Calculate blend using convex (489, 99)
# pixel :  26908
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576786698.566624 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# -------->no detection
# @@@@time is come 1576786705.3329961 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 80
# Cropping photo :  408 370 1002 530
# check4
# Detecting tail
# tail pixel :  2703
# Start scope for blen.
# Calculate blend using convex (497, 107)
# pixel :  28270
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# @@@@time is come 1576786711.6555488 True
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 31
# Cropping photo :  82 321 812 508
# check4
# Detecting tail
# tail pixel :  2090
# Start scope for blen.
# Calculate blend using convex (651, 147)
# pixel :  41152
# -------->No it's blend :  61.584508096136005
# @@@@time is come 1576786721.984193 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 52
# Cropping photo :  264 341 912 720
# check4
# Detecting tail
# tail pixel :  1970
# -------->No tail detected
# @@@@time is come 1576786758.094094 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 30
# Cropping photo :  154 194 886 576
# check4
# Detecting tail
# tail pixel :  5881
# Start scope for blen.
# Calculate blend using convex (559, 253)
# pixel :  43352
# -------->No it's blend :  46.96196635360133
# @@@@time is come 1576786768.095498 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 19
# Cropping photo :  154 212 820 576
# check4
# Detecting tail
# tail pixel :  5523
# Start scope for blen.
# Calculate blend using convex (557, 251)
# pixel :  43812
# -------->No it's blend :  47.46849843440199
# @@@@time is come 1576786849.460365 False
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# Start find the nearest chillie.
# Deleting noise 21
# Cropping photo :  154 196 888 578
# check4
# Detecting tail
# tail pixel :  6013
# Start scope for blen.
# Calculate blend using convex (559, 251)
# pixel :  43633
# -------->No it's blend :  47.31403166341357
# @@@@time is come 1576786851.558219 False
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-abcdf9c453d3> in <module>
#      21     #Wait for arduino to write
#      22                 #waitforreq=ser.read_until()
# ---> 23     if(ser.in_waiting):
#      24         waitforreq=ser.readline()
#      25     else:
#
# ~/anaconda3/lib/python3.7/site-packages/serial/serialposix.py in in_waiting(self)
#     465         """Return the number of bytes currently in the input buffer."""
#     466         #~ s = fcntl.ioctl(self.fd, termios.FIONREAD, TIOCM_zero_str)
# --> 467         s = fcntl.ioctl(self.fd, TIOCINQ, TIOCM_zero_str)
#     468         return struct.unpack('I', s)[0]
#     469
#
# OSError: [Errno 6] Device not configured

# %%
print(queue)
print(time.time())
# Out:
# [{'time': 1576783444.0862029, 'grb': True}, {'time': 1576783448.521217, 'grb': False}]
# 1576783546.896659

# %%
c50=0
c100=0
while True:    
    #Wait for arduino to write
    waitforreq=ser.read_until()
    #Display serial
    print("serial say : ",waitforreq)
    print("Requset code : ",waitforreq[0])
    if(waitforreq[0]==50):
        c50=c50+1
    elif(waitforreq[0]==100):
        c100=c100+1
    #Check is that really come from arduino
    if (waitforreq[0]!=50):
        continue
    
    #Try capture till got photo
    ret=False
    while (ret==False):
        print("Cam!")
        ret, frame = cap.read() # ret is boolean for pic avalble or not
    
    print("Cam've got shot!")
    
    frame=frame[...,::-1] # cv2 BRG to RGB
    frame=np.rot90(frame, 0, ) # rotate 90 degrees
    frame=frame[:,:] #crop the photo
    
    #Show raw photo
    if needplot:
        plt.imshow(frame)
        plt.show()

    #Calculate binary from R:G:B 1:1:0 and not black pixel R+G+B>700 is black
    binary=((((frame[:,:,0]/frame[:,:,2])+(frame[:,:,1]/frame[:,:,2]))>2.1)&(frame[:,:,0]+frame[:,:,1]+frame[:,:,2]<=700))
    
    #Show first binary
    plt.imshow(binary)
    plt.show()
    
    #Start label first binary
    labelframe=label(binary)
    regiongrframe=regionprops(labelframe)

    print("Start find the nearest chillie.")
    
    labelreal=-1 #lable that we choses defult -1
    yreal=0 #Parameter for dowst chilie
    minr, minc, maxr, maxc=0,0,0,0
    for j in range(len(regiongrframe)):
        area=regiongrframe[j].area
        y0,x0=regiongrframe[j].centroid
        #if area pixel less than 9000 assume as noise
        if area<9000:
            pass
        elif(y0>yreal and abs(750-x0)<=300):
            labelreal= regiongrframe[j].label
            yreal=y0
            minr, minc, maxr, maxc = regiongrframe[j].bbox
    
    #Notting deteccted
    if(labelreal==-1):
        print("-------->no detection")
        command=str.encode('0')
        ser.write(command)
        continue
    
    print("Deleting noise",labelreal)
    #New binary without noise
    binary=(labelframe==labelreal)
    #New frame with Black background
    frame[:,:,0]=frame[:,:,0]*binary
    frame[:,:,1]=frame[:,:,1]*binary
    frame[:,:,2]=frame[:,:,2]*binary
    
    #Crop img
    print("Cropping photo : ",minr,minc, maxr, maxc)
    binary=binary[minr:maxr+1,minc:maxc+1]
    frame=frame[minr:maxr+1,minc:maxc+1,:]

    print("check4")
    R=frame[:,:,0]
    G=frame[:,:,1]
    B=frame[:,:,2]
    #meanofrgb=(R+G+B)/1.65
    
    #biforblen is a binary of Chilie without tail
    print("Detecting tail")
    biforblen=(binary&(R>G*1.8)).copy()
    
    #Show tail (biforblen!=binary)=tail
    if needplot:
        plt.imshow(biforblen!=binary)
        plt.show()
    
    print("tail pixel : ",np.sum(biforblen!=binary))
    
    #if tail pixel less than 2000 mean no tail
    if (np.sum(biforblen!=binary)<2000):
        print("-------->No tail detected")
        #Sent false to arduino
        command=str.encode('0')
        ser.write(command)
        continue
    
    #groupping the real chilie body without tail
    labelframeforblen=label(biforblen)
    regiongrframeforblen=regionprops(labelframeforblen)

    print("Start scope for blen.")
    
    labelrealforblen=-1
    #yrealforblen keep maximum 
    yrealforblen=0
    minr, minc, maxr, maxc=0,0,0,0
    for j in range(len(regiongrframeforblen)):
        area=regiongrframeforblen[j].area
            #y0,x0=regiongrframeforblen[j].centroid
        #if area less that 9000px assume as noise
        if area<9000:
            pass
        elif(area>yrealforblen):
            labelrealforblen= regiongrframeforblen[j].label
            yrealforblen=area
            minr, minc, maxr, maxc = regiongrframeforblen[j].bbox  
    
    #Crop binary for convexhull
    biforblen=biforblen[minr:maxr+1,minc:maxc+1].copy()

    print("Calculate blend using convex" ,biforblen.shape )
    if needplot:
        plt.imshow(biforblen)
        plt.show()
    print("pixel : ",np.sum(biforblen))
    
    #Body of chillie less than 43000 assume as small or green ones
    if (np.sum(biforblen)<=24010):
        print("-------->it green or too small")
        command=str.encode('0')
        ser.write(command)
        continue
    
    #try assing convex hull to cvh
    try :
        cvh=convex_hull_image(biforblen)
    except:
        print("!!!!!!!!!convexhull not working!")
        cvh=biforblen
        
    #show covex hull
    if needplot:
        plt.imshow(cvh)
        plt.show()

    #if binary/convex hull less than 65 assume it is bleded
    if (np.sum(biforblen)*100/np.sum(cvh)<63):
        #return false
        print("-------->No it's blend : ",np.sum(biforblen)*100/np.sum(cvh))
        command=str.encode('0')
        ser.write(command)
        continue
    
    print("Transforme background to white")
    frame[(R+G+B)==0]=255
    img=Image.fromarray(frame)
    print("Calculating colour.")
    
    if needplot:
        plt.imshow(frame)
        plt.show()
    
    #Predict by ML model
    predict=model.predict({'image': img})['classLabel']
    
    #Good chilie detected
    if(predict=='red' or predict=='yellow' or predict=="orange"):
        #return true
        print("-------->Good chilie")
        command=str.encode('1')
        ser.write(command)
    else:
            #return false
        print("-------->chilie colour not good",predict)
        command=str.encode('0')
        ser.write(command)
    print("donee")
# Out:
# serial say :  b'2\r\n'
# Requset code :  50
# Cam!
# Cam've got shot!
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# /Users/macbook/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in greater
# Start find the nearest chillie.
# Deleting noise 268
# Cropping photo :  190 838 934 986
# check4
# Detecting tail
# tail pixel :  2418
# Start scope for blen.
# Calculate blend using convex (611, 98)
# pixel :  39119
# Transforme background to white
# Calculating colour.
# -------->Good chilie
# donee
# serial say :  b'queue : 2413200\r\n'
# Requset code :  113
# serial say :  b'dobad 2\r\n'
# Requset code :  100
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/serial/serialposix.py in read(self, size)
#     492                     break   # timeout
# --> 493                 buf = os.read(self.fd, size - len(read))
#     494                 # read should always return some data as select reported it was
#
# OSError: [Errno 6] Device not configured
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-6-fd7a93a64da0> in <module>
#       3 while True:
#       4     #Wait for arduino to write
# ----> 5     waitforreq=ser.read_until()
#       6     #Display serial
#       7     print("serial say : ",waitforreq)
#
# ~/anaconda3/lib/python3.7/site-packages/serial/serialutil.py in read_until(self, terminator, size)
#     657         timeout = Timeout(self._timeout)
#     658         while True:
# --> 659             c = self.read(1)
#     660             if c:
#     661                 line += c
#
# ~/anaconda3/lib/python3.7/site-packages/serial/serialposix.py in read(self, size)
#     507                 # https://www.python.org/dev/peps/pep-0475.
#     508                 if e.errno not in (errno.EAGAIN, errno.EALREADY, errno.EWOULDBLOCK, errno.EINPROGRESS, errno.EINTR):
# --> 509                     raise SerialException('read failed: {}'.format(e))
#     510             except select.error as e:
#     511                 # this is for Python 2.x
#
# SerialException: read failed: [Errno 6] Device not configured

# %%
print(c50,c100)
# Out:
# 11 7
